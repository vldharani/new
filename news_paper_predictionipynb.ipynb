# %%
#df.shape prints the no of columns and rows present in the dataset
#making an Sunday edition page based on prediction of the data

# %%
from google.colab import files
import pandas as pd

upload =files.upload()
a=list(upload.keys())[0]
data = pd.read_csv(a)
data
# Out:
#      <input type="file" id="files-b39293cc-a406-40f0-984c-efb35f4e18e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b39293cc-a406-40f0-984c-efb35f4e18e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data.shape
# Out:
# (34, 3)

# %%
data.isnull().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
data_new=data[['daily','sunday']]
data_new
# Out:
#        daily    sunday
# 0    391.952   488.506
# 1    516.981   798.298
# 2    355.628   235.084
# 3    238.555   299.451
# 4    537.780   559.093
# 5    733.775  1133.249
# 6    198.832   348.744
# 7    252.624   417.779
# 8    206.204   344.522
# 9    231.177   323.084
# 10   449.755   620.752
# 11   288.571   423.305
# 12   185.736   202.614
# 13  1164.388  1531.527
# 14   444.581   553.479
# 15   412.871   685.975
# 16   272.280   324.241
# 17   781.796   983.240
# 18  1209.225  1762.015
# 19   825.512   960.308
# 20   223.748   284.611
# 21   354.843   407.760
# 22   515.523   982.663
# 23   220.465   557.000
# 24   337.672   440.923
# 25   197.120   268.060
# 26   133.239   262.048
# 27   374.009   432.502
# 28   273.844   338.355
# 29   570.364   704.322
# 30   391.286   585.681
# 31   201.860   267.781
# 32   321.626   408.343
# 33   838.902  1165.567

# %%
data_new.corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
import statsmodels.formula.api as smf
model = smf.ols("sunday ~ daily", data=data).fit()

# %%
import seaborn as sns
sns.regplot(x='daily',y='sunday',data=data);

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
sns.scatterplot(x='daily', y='sunday', data=data)
sns.regplot(x='daily', y='sunday', data=data, scatter=False)
plt.title("Scatter Plot: Daily vs Sunday")
plt.show()
